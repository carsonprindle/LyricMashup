# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\Miniconda3\envs\py36\python.exe

# %%
import lyricsgenius as genius
api = genius.Genius(
    'tsbZ0e799qyZ9rhAHZvLfWD5LiI0VJkZjj1i03q3_oGPrgkgVry1YCDHTDk6eAEM')

# %%
artist = api.search_artist('Kanye West', max_songs=0)
# Out:
# Searching for Kanye West...
#
# Song 1: "'03 Electric Relaxation"
# Song 2: "18 Years"
# Song 3: "1996 Fat Beats Freestyle"
# Song 4: "2002 Unreleased Freestyle"
# Song 5: "2004 Tim Westwood Freestyle"
# Song 6: "2013 Yeezus Tour Dates"
# Song 7: "2013 Zane Lowe BBC Radio Interview Part 1"
# Song 8: "2013 Zane Lowe BBC Radio Interview Part 2"
# Song 9: "2014 Yeezus Tour Dates"
# Song 10: "2015 BET Honors Visionary Award Acceptance Speech"
#
# Reached user-specified song limit (10).
# Found 10 songs.
# Done.

# %%
runaway = api.search_song('Runaway',kanye.name)
print(runaway)
# Out:
# Searching for "Runaway"...
# Done.
# "Runaway" by Kanye West:
#     And I always find, yeah, I always find something wrong
#     You been putting up with my shit just way too...

# %%
kanye.add_song(runaway)
kanye.save_lyrics()
# Out:
# Wrote 11 songs to Lyrics_KanyeWest.json.
# {'artist': 'Kanye West',
#  'songs': [{'album': None,
#    'artist': 'Kanye West',
#    'image': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#    'lyrics': "You got to\n\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nAll day long man, we back in town\n\nHomie check it out I got her mesmerized\nSo won't you hook a chew scorns, she tellin you buy\nStreet poetry is how ya boy get paid\nAnd I wear no Escalade, metallic, black or beige\nYo when I walk up in the club you know I do not pay\nAiiyo my man Kanyeezy he got something to say\n\nAiiyo my name is Kanyeezy from the Roc-A fam\nAnd where the Glocks don't jam, so where we pop them scrams\nSee I showed you on the champions how we get down\nSo don't twist ya lips, I'm like Bobby Brown\nYou got B2K on all your bedroom wall\nBut if you be with Kan, gonna work ya walls\nStraight from the South side of dem Chi-town streets\nThe top three in the game, with these here beats\n\nAnd if you talk about him, aiiyo I take you out\nEither with the nine or the tech's in his mouth\nAnd let that dime gettin friendly than the orgie's at eight\nBut y'all niggas don't shine so you couldn't relate\n\nRelax yourself or we'll whack ya down (You couldn't relate)\nRelax yourself or we'll whack ya down (Yo Quence, you couldn't relate)\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\n\nQuence without the game, now he's back to ball\nDrive you insane, drop a tat at the mall\nYou starin at my Rolls' cold way to long\nBut I ain't scared of robbers, why I wear tephlon\nI took her on the ave and she expect me to trip\nBut I made up with no style while I bought me some kicks\nSo if you want the drama holler at ya boy\n\nOriginal rude boy like Pastor Troy\nThe G-500 is my favorite toy\nCause it don't look like a thug or a hood\nBut he keep dem gorilla's so we still be good\nBy the way my name is K, don't forget the A\nAnd the N-Y-E, out N.Y.C\nI'ma still rep the gold, no matter where I go\nEverybody say I'm hot, I'm sayin I'm cold\nHate when niggas leave the city and switch up they reps\nOn the real homie, I don't get down like that\nI'ma milk the game, 'til we all can eat\n\nNow the Chocolate Factory is what I bump in my jeep\nSo roll me up a L, but don't lace it with leak\nCause that shit'll have me zonin for a couple of weeks\n\nNow your momma told you let the Cleveland show\nCause that's the best way to get a nigga with dough\nThey're fakin pregnancies and Cartier tournier\nBut she ain't know I'm cheaper than IKEA furniture\n\nKanye, White, Malik, Little and D\nMenace, Skates to Lou and 'em Puffs from L.B\nThey know the Consequence be wearin gold and ice\nCause I got out the projects, where it's flooded with mice\nEy shorty let me tell you 'bout the rules of my Nikes\nIt seems they always keep on movin, I don't hear nuthin twice\n\nSo relax yourself or we'll whack ya down (Don't hear nuthin twice)\nRelax yourself or we'll whack ya down (Don't hear nuthin twice)\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down (Calm down)\nRelax yourself or we'll whack ya down (Yeah!)\nRelax yourself or we'll whack ya down (Yeah!)\nRelax yourself or we'll whack ya down (It's the R.O.C.!)\nRelax yourself or we'll whack ya down (Uhh)\nRelax yourself or we'll whack ya down (Yeah)\nRelax yourself or we'll whack ya down (Uh-huh, yeah)\nAll day long man, we back in town\n\nRelax yaself or we'll whack ya down",
#    'raw': {'album': None,
#     'annotation_count': 2,
#     'api_path': '/songs/1606392',
#     'current_user_metadata': {'excluded_permissions': ['follow',
#       'award_transcription_iq',
#       'remove_transcription_iq',
#       'see_pageviews',
#       'pyong',
#       'edit_lyrics',
#       'view_annotation_engagement_data',
#       'publish',
#       'unpublish',
#       'edit_spotify_details',
#       'hide',
#       'unhide',
#       'toggle_featured_video',
#       'add_pinned_annotation_to',
#       'add_community_annotation_to',
#       'destroy',
#       'mark_as_not_spam',
#       'edit_spotify_annotations_for',
#       'verify_lyrics',
#       'unverify_lyrics',
#       'edit_anything',
#       'edit_album_appearances',
#       'edit_any_media',
#       'edit',
#       'rename',
#       'edit_tags',
#       'watch_fact_track',
#       'reindex',
#       'view_lyrics_synchronization',
#       'enable_media',
#       'disable_media',
#       'edit_lyrics_or_annotation_brackets',
#       'see_editorial_indicators',
#       'view_attribution_visualization',
#       'edit_youtube_url',
#       'edit_soundcloud_url',
#       'edit_spotify_uuid',
#       'edit_apple_music_url',
#       'edit_vevo_url',
#       'moderate_annotations',
#       'create_annotation',
#       'see_short_id',
#       'manage_chart_item',
#       'create_tag'],
#      'interactions': {'following': False, 'pyong': False},
#      'iq_by_action': {},
#      'permissions': ['create_comment', 'view_song_story_gallery'],
#      'relationships': {}},
#     'custom_performances': [],
#     'description': {'dom': {'children': [{'children': ['Kanye West and Consequence team up and spit verses over A Tribe Called Quest’s “Electric Relaxation”.'],
#         'tag': 'p'}],
#       'tag': 'root'}},
#     'description_annotation': {'_type': 'referent',
#      'annotatable': {'api_path': '/songs/1606392',
#       'client_timestamps': {'lyrics_updated_at': 1507361330,
#        'updated_by_human_at': 1507361350},
#       'context': 'Kanye West',
#       'id': 1606392,
#       'image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#       'link_title': "'03 Electric Relaxation by\xa0Kanye\xa0West (Ft.\xa0Consequence)",
#       'title': "'03 Electric Relaxation",
#       'type': 'Song',
#       'url': 'https://genius.com/Kanye-west-03-electric-relaxation-lyrics'},
#      'annotations': [{'api_path': '/annotations/6121172',
#        'authors': [{'attribution': 1.0,
#          'pinned_role': None,
#          'user': {'api_path': '/users/1777241',
#           'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#             'url': 'https://assets.genius.com/images/default_avatar_300.png?1523560690'},
#            'small': {'bounding_box': {'height': 100, 'width': 100},
#             'url': 'https://assets.genius.com/images/default_avatar_100.png?1523560690'},
#            'thumb': {'bounding_box': {'height': 32, 'width': 32},
#             'url': 'https://assets.genius.com/images/default_avatar_32.png?1523560690'},
#            'tiny': {'bounding_box': {'height': 16, 'width': 16},
#             'url': 'https://assets.genius.com/images/default_avatar_16.png?1523560690'}},
#           'current_user_metadata': {'excluded_permissions': ['follow'],
#            'features': [],
#            'interactions': {'following': False},
#            'permissions': []},
#           'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1523560690',
#           'human_readable_role_for_display': None,
#           'id': 1777241,
#           'iq': 7,
#           'login': 'victormedina329',
#           'name': 'victormedina329',
#           'role_for_display': None,
#           'url': 'https://genius.com/victormedina329'}}],
#        'body': {'dom': {'children': [{'children': ['Kanye West and Consequence team up and spit verses over A Tribe Called Quest’s “Electric Relaxation”.'],
#            'tag': 'p'}],
#          'tag': 'root'}},
#        'comment_count': 0,
#        'community': True,
#        'cosigned_by': [],
#        'current_user_metadata': {'excluded_permissions': ['vote',
#          'edit',
#          'cosign',
#          'uncosign',
#          'destroy',
#          'accept',
#          'reject',
#          'see_unreviewed',
#          'clear_votes',
#          'propose_edit_to',
#          'pin_to_profile',
#          'unpin_from_profile',
#          'update_source',
#          'set_brand',
#          'clear_brand',
#          'edit_custom_preview'],
#         'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#         'iq_by_action': {},
#         'permissions': ['create_comment']},
#        'custom_preview': None,
#        'has_voters': True,
#        'id': 6121172,
#        'pinned': False,
#        'rejection_comment': None,
#        'share_url': 'https://genius.com/6121172',
#        'source': None,
#        'state': 'pending',
#        'url': 'https://genius.com/6121172/Kanye-west-03-electric-relaxation/03-electric-relaxation',
#        'verified': False,
#        'verified_by': None,
#        'votes_total': 2}],
#      'annotator_id': 1777241,
#      'annotator_login': 'victormedina329',
#      'api_path': '/referents/6121172',
#      'classification': 'unreviewed',
#      'fragment': "'03 Electric Relaxation",
#      'id': 6121172,
#      'is_description': True,
#      'path': '/6121172/Kanye-west-03-electric-relaxation/03-electric-relaxation',
#      'range': {'content': "'03 Electric Relaxation"},
#      'song_id': 1606392,
#      'url': 'https://genius.com/6121172/Kanye-west-03-electric-relaxation/03-electric-relaxation',
#      'verified_annotator_ids': []},
#     'embed_content': "<div id='rg_embed_link_1606392' class='rg_embed_link' data-song-id='1606392'>Read <a href='https://genius.com/Kanye-west-03-electric-relaxation-lyrics'>“'03 Electric Relaxation” by Kanye\xa0West</a> on Genius</div> <script crossorigin src='//genius.com/songs/1606392/embed.js'></script>",
#     'featured_artists': [{'api_path': '/artists/344',
#       'header_image_url': 'https://s3.amazonaws.com/rapgenius/1362131146_Consequence.png',
#       'id': 344,
#       'image_url': 'https://s3.amazonaws.com/rapgenius/1362131146_Consequence.png',
#       'iq': 2165,
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Consequence',
#       'url': 'https://genius.com/artists/Consequence'}],
#     'featured_video': False,
#     'full_title': "'03 Electric Relaxation by\xa0Kanye\xa0West (Ft.\xa0Consequence)",
#     'header_image_thumbnail_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#     'id': 1606392,
#     'lyrics': "You got to\n\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nAll day long man, we back in town\n\nHomie check it out I got her mesmerized\nSo won't you hook a chew scorns, she tellin you buy\nStreet poetry is how ya boy get paid\nAnd I wear no Escalade, metallic, black or beige\nYo when I walk up in the club you know I do not pay\nAiiyo my man Kanyeezy he got something to say\n\nAiiyo my name is Kanyeezy from the Roc-A fam\nAnd where the Glocks don't jam, so where we pop them scrams\nSee I showed you on the champions how we get down\nSo don't twist ya lips, I'm like Bobby Brown\nYou got B2K on all your bedroom wall\nBut if you be with Kan, gonna work ya walls\nStraight from the South side of dem Chi-town streets\nThe top three in the game, with these here beats\n\nAnd if you talk about him, aiiyo I take you out\nEither with the nine or the tech's in his mouth\nAnd let that dime gettin friendly than the orgie's at eight\nBut y'all niggas don't shine so you couldn't relate\n\nRelax yourself or we'll whack ya down (You couldn't relate)\nRelax yourself or we'll whack ya down (Yo Quence, you couldn't relate)\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\n\nQuence without the game, now he's back to ball\nDrive you insane, drop a tat at the mall\nYou starin at my Rolls' cold way to long\nBut I ain't scared of robbers, why I wear tephlon\nI took her on the ave and she expect me to trip\nBut I made up with no style while I bought me some kicks\nSo if you want the drama holler at ya boy\n\nOriginal rude boy like Pastor Troy\nThe G-500 is my favorite toy\nCause it don't look like a thug or a hood\nBut he keep dem gorilla's so we still be good\nBy the way my name is K, don't forget the A\nAnd the N-Y-E, out N.Y.C\nI'ma still rep the gold, no matter where I go\nEverybody say I'm hot, I'm sayin I'm cold\nHate when niggas leave the city and switch up they reps\nOn the real homie, I don't get down like that\nI'ma milk the game, 'til we all can eat\n\nNow the Chocolate Factory is what I bump in my jeep\nSo roll me up a L, but don't lace it with leak\nCause that shit'll have me zonin for a couple of weeks\n\nNow your momma told you let the Cleveland show\nCause that's the best way to get a nigga with dough\nThey're fakin pregnancies and Cartier tournier\nBut she ain't know I'm cheaper than IKEA furniture\n\nKanye, White, Malik, Little and D\nMenace, Skates to Lou and 'em Puffs from L.B\nThey know the Consequence be wearin gold and ice\nCause I got out the projects, where it's flooded with mice\nEy shorty let me tell you 'bout the rules of my Nikes\nIt seems they always keep on movin, I don't hear nuthin twice\n\nSo relax yourself or we'll whack ya down (Don't hear nuthin twice)\nRelax yourself or we'll whack ya down (Don't hear nuthin twice)\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down\nRelax yourself or we'll whack ya down (Calm down)\nRelax yourself or we'll whack ya down (Yeah!)\nRelax yourself or we'll whack ya down (Yeah!)\nRelax yourself or we'll whack ya down (It's the R.O.C.!)\nRelax yourself or we'll whack ya down (Uhh)\nRelax yourself or we'll whack ya down (Yeah)\nRelax yourself or we'll whack ya down (Uh-huh, yeah)\nAll day long man, we back in town\n\nRelax yaself or we'll whack ya down",
#     'lyrics_owner_id': 3084661,
#     'lyrics_state': 'complete',
#     'media': [],
#     'path': '/Kanye-west-03-electric-relaxation-lyrics',
#     'primary_artist': {'api_path': '/artists/72',
#      'header_image_url': 'https://images.genius.com/93a98116162c07aa60e8a15fe7fb6977.800x480x1.jpg',
#      'id': 72,
#      'image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Kanye West',
#      'url': 'https://genius.com/artists/Kanye-west'},
#     'producer_artists': [],
#     'pyongs_count': None,
#     'recording_location': None,
#     'release_date': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#     'song_relationships': [{'songs': [], 'type': 'samples'},
#      {'songs': [], 'type': 'sampled_in'},
#      {'songs': [], 'type': 'interpolates'},
#      {'songs': [], 'type': 'interpolated_by'},
#      {'songs': [], 'type': 'cover_of'},
#      {'songs': [], 'type': 'covered_by'},
#      {'songs': [], 'type': 'remix_of'},
#      {'songs': [], 'type': 'remixed_by'},
#      {'songs': [], 'type': 'live_version_of'},
#      {'songs': [], 'type': 'performed_live_as'}],
#     'stats': {'accepted_annotations': 0,
#      'contributors': 5,
#      'hot': False,
#      'iq_earners': 4,
#      'transcribers': 2,
#      'unreviewed_annotations': 2,
#      'verified_annotations': 0},
#     'title': "'03 Electric Relaxation",
#     'title_with_featured': "'03 Electric Relaxation (Ft.\xa0Consequence)",
#     'url': 'https://genius.com/Kanye-west-03-electric-relaxation-lyrics',
#     'verified_annotations_by': [],
#     'verified_contributors': [],
#     'verified_lyrics_by': [],
#     'writer_artists': []},
#    'title': "'03 Electric Relaxation",
#    'year': None},
#   {'album': 'Def Poetry Jam',
#    'artist': 'Kanye West',
#    'image': 'https://images.genius.com/233f5cd918ed962d168eeb68666807ab.1000x563x1.jpg',
#    'lyrics': 'The next guest.. is my man\nBringing him back, its a pleasure to have him here\nPlease give it for my brother Kanye.. West\n\n\nUh.. Let me stop-by..\nThanking you know.. for allowing me to come back because this is one of the important days of the year to... next to y\'know Christmas, my mother\'s birthday and my birthday\nNow here goes the story...\nMy momma calls me and she says "Baby, I\'m down in Miami and they play your song all day long. You making a lot of money right now. So when you on the tour I know there\'s gonna be lot of girls out there tryna throw you their pussy"\n(haha) I mean that\'s how my momma talks with me\nShe says "Baby, imma want you to put three rubbers cause I don\'t want no girl out there fucking up our money\n\nEighteen years, eighteen years\nShe got one of your kids, got you for eighteen years\nI know a nigga payin\' child support for one of his kids\nHis baby mama car and crib is bigger than his\nYou will see him on TV any given Sunday\nWin the Super Bowl and drive off in a Hyundai\nShe was supposed to buy your shorty Tyco with your money\nShe went to the doctor, got lipo with your money\nShe walkin\' around lookin\' like Michael with your money\nShould\'ve got that insured, Geico for your money\nIf you ain\'t no punk\nHolla, "We want prenup! We want prenup!" (Yeah!)\nIt\'s somethin\' that you need to have\n‘Cause when she leave yo\' ass, she gon\' leave with half\nEighteen years, eighteen years\nShe got one of your kids, got you for eighteen years\nAnd on the 18th birthday he found out it wasn\'t his!\nMaaan! he killed that bitch, they gave him 25 years, 25 years\nYeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah..',
#    'raw': {'album': {'api_path': '/albums/107358',
#      'artist': {'api_path': '/artists/2724',
#       'header_image_url': 'https://images.genius.com/8f555e0fe9a554f5a97fe0a3f491954d.1000x1000x1.jpg',
#       'id': 2724,
#       'image_url': 'https://images.genius.com/8f555e0fe9a554f5a97fe0a3f491954d.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Russell Simmons',
#       'url': 'https://genius.com/artists/Russell-simmons'},
#      'cover_art_url': 'https://images.genius.com/2ba45279dc14611f186ea61531cb027f.331x331x1.jpg',
#      'full_title': 'Def Poetry Jam by Russell Simmons',
#      'id': 107358,
#      'name': 'Def Poetry Jam',
#      'url': 'https://genius.com/albums/Russell-simmons/Def-poetry-jam'},
#     'annotation_count': 1,
#     'api_path': '/songs/3187721',
#     'current_user_metadata': {'excluded_permissions': ['follow',
#       'award_transcription_iq',
#       'remove_transcription_iq',
#       'see_pageviews',
#       'pyong',
#       'edit_lyrics',
#       'view_annotation_engagement_data',
#       'publish',
#       'unpublish',
#       'edit_spotify_details',
#       'hide',
#       'unhide',
#       'toggle_featured_video',
#       'add_pinned_annotation_to',
#       'add_community_annotation_to',
#       'destroy',
#       'mark_as_not_spam',
#       'edit_spotify_annotations_for',
#       'verify_lyrics',
#       'unverify_lyrics',
#       'edit_anything',
#       'edit_album_appearances',
#       'edit_any_media',
#       'edit',
#       'rename',
#       'edit_tags',
#       'watch_fact_track',
#       'reindex',
#       'view_lyrics_synchronization',
#       'enable_media',
#       'disable_media',
#       'edit_lyrics_or_annotation_brackets',
#       'see_editorial_indicators',
#       'view_attribution_visualization',
#       'edit_youtube_url',
#       'edit_soundcloud_url',
#       'edit_spotify_uuid',
#       'edit_apple_music_url',
#       'edit_vevo_url',
#       'moderate_annotations',
#       'create_annotation',
#       'see_short_id',
#       'manage_chart_item',
#       'create_tag'],
#      'interactions': {'following': False, 'pyong': False},
#      'iq_by_action': {},
#      'permissions': ['create_comment', 'view_song_story_gallery'],
#      'relationships': {}},
#     'custom_performances': [{'artists': [{'api_path': '/artists/156',
#         'header_image_url': 'https://images.genius.com/4d1a9757d430776710118a3e0ba4658f.1000x667x1.jpg',
#         'id': 156,
#         'image_url': 'https://images.genius.com/4d1a9757d430776710118a3e0ba4658f.1000x667x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Yasiin Bey',
#         'url': 'https://genius.com/artists/Yasiin-bey'}],
#       'label': 'Hosted by'},
#      {'artists': [{'api_path': '/artists/2724',
#         'header_image_url': 'https://images.genius.com/8f555e0fe9a554f5a97fe0a3f491954d.1000x1000x1.jpg',
#         'id': 2724,
#         'image_url': 'https://images.genius.com/8f555e0fe9a554f5a97fe0a3f491954d.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Russell Simmons',
#         'url': 'https://genius.com/artists/Russell-simmons'}],
#       'label': 'Show produced by'}],
#     'description': {'dom': {'children': [{'children': [{'children': ['18 Years'],
#           'tag': 'em'},
#          ' is a slam poetry delivered by Kanye on Def Poetry Jam series hosted by ',
#          {'attributes': {'href': 'https://genius.com/artists/YasiinBey'},
#           'children': ['Mos Def'],
#           'data': {'api_path': '/artists/156'},
#           'tag': 'a'},
#          '. It was the last performance of the second episode of the fifth season.'],
#         'tag': 'p'},
#        '',
#        {'children': ['Kanye has previously performed on the show in ',
#          {'attributes': {'href': 'https://genius.com/Kanye-west-self-conscious-aka-yeah-lyrics'},
#           'children': ['Season 3'],
#           'data': {'api_path': '/songs/3408'},
#           'tag': 'a'},
#          ' and also delivered poetry titled ',
#          {'children': [{'attributes': {'href': 'https://genius.com/Kanye-west-bitter-sweet-annotated'},
#             'children': ['Bittersweet'],
#             'data': {'api_path': '/songs/266749'},
#             'tag': 'a'}],
#           'tag': 'em'},
#          ' in the episode 7 of season 5.'],
#         'tag': 'p'},
#        '',
#        {'children': ['This performance was used in the second verse of Kanye’s Grammy winning single ',
#          {'children': [{'attributes': {'href': 'https://genius.com/Kanye-west-gold-digger-lyrics'},
#             'children': ['Golddigger'],
#             'data': {'api_path': '/songs/1267'},
#             'tag': 'a'}],
#           'tag': 'em'},
#          ' which was released weeks later.'],
#         'tag': 'p'}],
#       'tag': 'root'}},
#     'description_annotation': {'_type': 'referent',
#      'annotatable': {'api_path': '/songs/3187721',
#       'client_timestamps': {'lyrics_updated_at': 1502104527,
#        'updated_by_human_at': 1508511663},
#       'context': 'Kanye West',
#       'id': 3187721,
#       'image_url': 'https://images.genius.com/233f5cd918ed962d168eeb68666807ab.1000x563x1.jpg',
#       'link_title': '18 Years by\xa0Kanye\xa0West (Ft.\xa0Yasiin\xa0Bey)',
#       'title': '18 Years',
#       'type': 'Song',
#       'url': 'https://genius.com/Kanye-west-18-years-lyrics'},
#      'annotations': [{'api_path': '/annotations/12472362',
#        'authors': [{'attribution': 1.0,
#          'pinned_role': None,
#          'user': {'api_path': '/users/3997326',
#           'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#             'url': 'https://images.genius.com/avatars/medium/a2751d45eadb0d09472b65d6c05fb28b'},
#            'small': {'bounding_box': {'height': 100, 'width': 100},
#             'url': 'https://images.genius.com/avatars/small/a2751d45eadb0d09472b65d6c05fb28b'},
#            'thumb': {'bounding_box': {'height': 32, 'width': 32},
#             'url': 'https://images.genius.com/avatars/thumb/a2751d45eadb0d09472b65d6c05fb28b'},
#            'tiny': {'bounding_box': {'height': 16, 'width': 16},
#             'url': 'https://images.genius.com/avatars/tiny/a2751d45eadb0d09472b65d6c05fb28b'}},
#           'current_user_metadata': {'excluded_permissions': ['follow'],
#            'features': [],
#            'interactions': {'following': False},
#            'permissions': []},
#           'header_image_url': 'https://images.genius.com/avatars/medium/a2751d45eadb0d09472b65d6c05fb28b',
#           'human_readable_role_for_display': 'Contributor',
#           'id': 3997326,
#           'iq': 6107,
#           'login': 'heisenburgerr',
#           'name': 'heisenburgerr',
#           'role_for_display': 'contributor',
#           'url': 'https://genius.com/heisenburgerr'}}],
#        'body': {'dom': {'children': [{'children': [{'children': ['18 Years'],
#              'tag': 'em'},
#             ' is a slam poetry delivered by Kanye on Def Poetry Jam series hosted by ',
#             {'attributes': {'href': 'https://genius.com/artists/YasiinBey'},
#              'children': ['Mos Def'],
#              'data': {'api_path': '/artists/156'},
#              'tag': 'a'},
#             '. It was the last performance of the second episode of the fifth season.'],
#            'tag': 'p'},
#           '',
#           {'children': ['Kanye has previously performed on the show in ',
#             {'attributes': {'href': 'https://genius.com/Kanye-west-self-conscious-aka-yeah-lyrics'},
#              'children': ['Season 3'],
#              'data': {'api_path': '/songs/3408'},
#              'tag': 'a'},
#             ' and also delivered poetry titled ',
#             {'children': [{'attributes': {'href': 'https://genius.com/Kanye-west-bitter-sweet-annotated'},
#                'children': ['Bittersweet'],
#                'data': {'api_path': '/songs/266749'},
#                'tag': 'a'}],
#              'tag': 'em'},
#             ' in the episode 7 of season 5.'],
#            'tag': 'p'},
#           '',
#           {'children': ['This performance was used in the second verse of Kanye’s Grammy winning single ',
#             {'children': [{'attributes': {'href': 'https://genius.com/Kanye-west-gold-digger-lyrics'},
#                'children': ['Golddigger'],
#                'data': {'api_path': '/songs/1267'},
#                'tag': 'a'}],
#              'tag': 'em'},
#             ' which was released weeks later.'],
#            'tag': 'p'}],
#          'tag': 'root'}},
#        'comment_count': 0,
#        'community': True,
#        'cosigned_by': [],
#        'current_user_metadata': {'excluded_permissions': ['vote',
#          'edit',
#          'cosign',
#          'uncosign',
#          'destroy',
#          'accept',
#          'reject',
#          'see_unreviewed',
#          'clear_votes',
#          'propose_edit_to',
#          'pin_to_profile',
#          'unpin_from_profile',
#          'update_source',
#          'set_brand',
#          'clear_brand',
#          'edit_custom_preview'],
#         'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#         'iq_by_action': {},
#         'permissions': ['create_comment']},
#        'custom_preview': None,
#        'has_voters': True,
#        'id': 12472362,
#        'pinned': False,
#        'rejection_comment': None,
#        'share_url': 'https://genius.com/12472362',
#        'source': None,
#        'state': 'pending',
#        'url': 'https://genius.com/12472362/Kanye-west-18-years/18-years',
#        'verified': False,
#        'verified_by': None,
#        'votes_total': 1}],
#      'annotator_id': 3997326,
#      'annotator_login': 'heisenburgerr',
#      'api_path': '/referents/12472362',
#      'classification': 'unreviewed',
#      'fragment': '18 Years',
#      'id': 12472362,
#      'is_description': True,
#      'path': '/12472362/Kanye-west-18-years/18-years',
#      'range': {'content': '18 Years'},
#      'song_id': 3187721,
#      'url': 'https://genius.com/12472362/Kanye-west-18-years/18-years',
#      'verified_annotator_ids': []},
#     'embed_content': "<div id='rg_embed_link_3187721' class='rg_embed_link' data-song-id='3187721'>Read <a href='https://genius.com/Kanye-west-18-years-lyrics'>“18 Years” by Kanye\xa0West</a> on Genius</div> <script crossorigin src='//genius.com/songs/3187721/embed.js'></script>",
#     'featured_artists': [{'api_path': '/artists/156',
#       'header_image_url': 'https://images.genius.com/4d1a9757d430776710118a3e0ba4658f.1000x667x1.jpg',
#       'id': 156,
#       'image_url': 'https://images.genius.com/4d1a9757d430776710118a3e0ba4658f.1000x667x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Yasiin Bey',
#       'url': 'https://genius.com/artists/Yasiin-bey'}],
#     'featured_video': False,
#     'full_title': '18 Years by\xa0Kanye\xa0West (Ft.\xa0Yasiin\xa0Bey)',
#     'header_image_thumbnail_url': 'https://images.genius.com/f394a9c4bb435d8c8c6b6721a3687838.300x221x1.jpg',
#     'header_image_url': 'https://images.genius.com/f394a9c4bb435d8c8c6b6721a3687838.450x331x1.jpg',
#     'id': 3187721,
#     'lyrics': 'The next guest.. is my man\nBringing him back, its a pleasure to have him here\nPlease give it for my brother Kanye.. West\n\n\nUh.. Let me stop-by..\nThanking you know.. for allowing me to come back because this is one of the important days of the year to... next to y\'know Christmas, my mother\'s birthday and my birthday\nNow here goes the story...\nMy momma calls me and she says "Baby, I\'m down in Miami and they play your song all day long. You making a lot of money right now. So when you on the tour I know there\'s gonna be lot of girls out there tryna throw you their pussy"\n(haha) I mean that\'s how my momma talks with me\nShe says "Baby, imma want you to put three rubbers cause I don\'t want no girl out there fucking up our money\n\nEighteen years, eighteen years\nShe got one of your kids, got you for eighteen years\nI know a nigga payin\' child support for one of his kids\nHis baby mama car and crib is bigger than his\nYou will see him on TV any given Sunday\nWin the Super Bowl and drive off in a Hyundai\nShe was supposed to buy your shorty Tyco with your money\nShe went to the doctor, got lipo with your money\nShe walkin\' around lookin\' like Michael with your money\nShould\'ve got that insured, Geico for your money\nIf you ain\'t no punk\nHolla, "We want prenup! We want prenup!" (Yeah!)\nIt\'s somethin\' that you need to have\n‘Cause when she leave yo\' ass, she gon\' leave with half\nEighteen years, eighteen years\nShe got one of your kids, got you for eighteen years\nAnd on the 18th birthday he found out it wasn\'t his!\nMaaan! he killed that bitch, they gave him 25 years, 25 years\nYeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah..',
#     'lyrics_owner_id': 3997326,
#     'lyrics_state': 'complete',
#     'media': [{'provider': 'youtube',
#       'start': 0,
#       'type': 'video',
#       'url': 'http://www.youtube.com/watch?v=jq1h0O48k90'}],
#     'path': '/Kanye-west-18-years-lyrics',
#     'primary_artist': {'api_path': '/artists/72',
#      'header_image_url': 'https://images.genius.com/93a98116162c07aa60e8a15fe7fb6977.800x480x1.jpg',
#      'id': 72,
#      'image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Kanye West',
#      'url': 'https://genius.com/artists/Kanye-west'},
#     'producer_artists': [],
#     'pyongs_count': None,
#     'recording_location': None,
#     'release_date': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/233f5cd918ed962d168eeb68666807ab.300x169x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/233f5cd918ed962d168eeb68666807ab.1000x563x1.jpg',
#     'song_relationships': [{'songs': [], 'type': 'samples'},
#      {'songs': [], 'type': 'sampled_in'},
#      {'songs': [], 'type': 'interpolates'},
#      {'songs': [], 'type': 'interpolated_by'},
#      {'songs': [], 'type': 'cover_of'},
#      {'songs': [], 'type': 'covered_by'},
#      {'songs': [], 'type': 'remix_of'},
#      {'songs': [], 'type': 'remixed_by'},
#      {'songs': [{'annotation_count': 34,
#         'api_path': '/songs/1267',
#         'full_title': 'Gold Digger by\xa0Kanye\xa0West (Ft.\xa0Jamie\xa0Foxx)',
#         'header_image_thumbnail_url': 'https://images.genius.com/20be4a5ccc57daf3577b7e0d12f092f8.300x300x1.jpg',
#         'header_image_url': 'https://images.genius.com/20be4a5ccc57daf3577b7e0d12f092f8.1000x1000x1.jpg',
#         'id': 1267,
#         'lyrics_owner_id': 7,
#         'lyrics_state': 'complete',
#         'path': '/Kanye-west-gold-digger-lyrics',
#         'primary_artist': {'api_path': '/artists/72',
#          'header_image_url': 'https://images.genius.com/93a98116162c07aa60e8a15fe7fb6977.800x480x1.jpg',
#          'id': 72,
#          'image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#          'is_meme_verified': False,
#          'is_verified': False,
#          'name': 'Kanye West',
#          'url': 'https://genius.com/artists/Kanye-west'},
#         'pyongs_count': 113,
#         'song_art_image_thumbnail_url': 'https://images.genius.com/12689354b232f124a23df209cc8659b4.300x300x1.jpg',
#         'stats': {'concurrents': 6,
#          'hot': False,
#          'pageviews': 1210798,
#          'unreviewed_annotations': 0},
#         'title': 'Gold Digger',
#         'title_with_featured': 'Gold Digger (Ft.\xa0Jamie\xa0Foxx)',
#         'url': 'https://genius.com/Kanye-west-gold-digger-lyrics'}],
#       'type': 'live_version_of'},
#      {'songs': [], 'type': 'performed_live_as'}],
#     'stats': {'accepted_annotations': 0,
#      'contributors': 1,
#      'hot': False,
#      'iq_earners': 1,
#      'transcribers': 1,
#      'unreviewed_annotations': 1,
#      'verified_annotations': 0},
#     'title': '18 Years',
#     'title_with_featured': '18 Years (Ft.\xa0Yasiin\xa0Bey)',
#     'url': 'https://genius.com/Kanye-west-18-years-lyrics',
#     'verified_annotations_by': [],
#     'verified_contributors': [],
#     'verified_lyrics_by': [],
#     'writer_artists': [{'api_path': '/artists/72',
#       'header_image_url': 'https://images.genius.com/93a98116162c07aa60e8a15fe7fb6977.800x480x1.jpg',
#       'id': 72,
#       'image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Kanye West',
#       'url': 'https://genius.com/artists/Kanye-west'}]},
#    'title': '18 Years',
#    'year': None},
#   {'album': None,
#    'artist': 'Kanye West',
#    'image': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#    'lyrics': "Yo it's the Lake Shore Drive\nKeep it live, tight, raw\nYou better hurry up, they can't keep it in the store\nTo be the format, your whole style on one beat\nInsert the disk, watch a nigga press delete\nTryna flex your technique\nYou gettin' blasted with a TEC, that shit is mad ironic\nLike Alanis Morisette, you try but can't jet\nBunch of airline lyrics, rhymes for low fare\nFlyin' out of O'Hare\nWhile these no-name ass niggas wanna go there, nobodies\nLivin' three blocks from nowhere, down the street from nothin'\nLet me show these niggas somethin', visual aid, the page\nAnd the nigga who fronted, word to God, they don't want it\nBut they wanna play the role, actin' hardcore\nWatch the whole career, flow, my style is too cold\nAlways, forever like Luther, but it ain't original\nBecause I stole it from the future, now I'm wanted in three centuries\nThe verbal killin', ask me where I got the style\nTold 'em from my grandchildren, put it on files\nDocument it in the books\nYou niggas can't see me so cease the hard looks\nI'll rather it get took\nLive and die for rhymes, dedicated to hip-hop\nShit don't stop\nNiggas they wanna know what and who's next\nAnd you roll up in a Lex\nThat's the train stop, my brain drop mad lyrics\nI rhyme with the spirit off the top, I drop nonstop\nVerbally killin', my style is ready to willin'\nY'all niggas stay back chillin'\nLike EPMD y'all niggas ain't seein' me, what\nWe're enormous, nah, do or die\nI got the rhymes on the brain\nThey tried to bomb me on the plane so I rode the train\nBefore I got here, spawned here\nI'm 'bout to save this shit, yo it's my year, what!?\nBring it on, pass it to my man Tariq\nRock the mic all week",
#    'raw': {'album': None,
#     'annotation_count': 13,
#     'api_path': '/songs/480181',
#     'current_user_metadata': {'excluded_permissions': ['follow',
#       'award_transcription_iq',
#       'remove_transcription_iq',
#       'pyong',
#       'edit_lyrics',
#       'view_annotation_engagement_data',
#       'publish',
#       'unpublish',
#       'edit_spotify_details',
#       'hide',
#       'unhide',
#       'toggle_featured_video',
#       'add_pinned_annotation_to',
#       'add_community_annotation_to',
#       'destroy',
#       'mark_as_not_spam',
#       'edit_spotify_annotations_for',
#       'verify_lyrics',
#       'unverify_lyrics',
#       'edit_anything',
#       'edit_album_appearances',
#       'edit_any_media',
#       'edit',
#       'rename',
#       'edit_tags',
#       'watch_fact_track',
#       'reindex',
#       'view_lyrics_synchronization',
#       'enable_media',
#       'disable_media',
#       'edit_lyrics_or_annotation_brackets',
#       'see_editorial_indicators',
#       'view_attribution_visualization',
#       'edit_youtube_url',
#       'edit_soundcloud_url',
#       'edit_spotify_uuid',
#       'edit_apple_music_url',
#       'edit_vevo_url',
#       'moderate_annotations',
#       'create_annotation',
#       'see_short_id',
#       'manage_chart_item',
#       'create_tag'],
#      'interactions': {'following': False, 'pyong': False},
#      'iq_by_action': {},
#      'permissions': ['see_pageviews',
#       'create_comment',
#       'view_song_story_gallery'],
#      'relationships': {}},
#     'custom_performances': [],
#     'description': {'dom': {'children': [{'children': ['NYC record store Fat Beats relocated in 1996 and celebrated their move by hosting a cypher including the likes of ',
#          {'attributes': {'href': 'https://genius.com/artists/Ill-bill'},
#           'children': ['Ill Bill'],
#           'data': {'api_path': '/artists/1780'},
#           'tag': 'a'},
#          ', ',
#          {'attributes': {'href': 'https://genius.com/artists/Lord-finesse'},
#           'children': ['Lord Finesse'],
#           'data': {'api_path': '/artists/430'},
#           'tag': 'a'},
#          ', ',
#          {'attributes': {'href': 'https://genius.com/artists/Al-tariq'},
#           'children': ["Al' Tariq"],
#           'data': {'api_path': '/artists/3047'},
#           'tag': 'a'},
#          ', ',
#          {'attributes': {'href': 'https://genius.com/artists/Xzibit'},
#           'children': ['Xzibit'],
#           'data': {'api_path': '/artists/291'},
#           'tag': 'a'},
#          ', etc. Out of all of these big names, the 19 year old ',
#          {'attributes': {'href': 'https://genius.com/artists/Kanye-west'},
#           'children': ['Kanye West'],
#           'data': {'api_path': '/artists/72'},
#           'tag': 'a'},
#          ' stood out, debuting this amazing freestyle that would forecast the bright future he would create for himself.'],
#         'tag': 'p'}],
#       'tag': 'root'}},
#     'description_annotation': {'_type': 'referent',
#      'annotatable': {'api_path': '/songs/480181',
#       'client_timestamps': {'lyrics_updated_at': 1496206369,
#        'updated_by_human_at': 1496206369},
#       'context': 'Kanye West',
#       'id': 480181,
#       'image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#       'link_title': '1996 Fat Beats Freestyle by\xa0Kanye\xa0West',
#       'title': '1996 Fat Beats Freestyle',
#       'type': 'Song',
#       'url': 'https://genius.com/Kanye-west-1996-fat-beats-freestyle-lyrics'},
#      'annotations': [{'api_path': '/annotations/3615761',
#        'authors': [{'attribution': 0.9310344827586207,
#          'pinned_role': None,
#          'user': {'api_path': '/users/104344',
#           'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#             'url': 'https://images.genius.com/9ac64405f08557cbf4062b5ca37643e6.1000x1000x1.jpg'},
#            'small': {'bounding_box': {'height': 100, 'width': 100},
#             'url': 'https://images.genius.com/9ac64405f08557cbf4062b5ca37643e6.1000x1000x1.jpg'},
#            'thumb': {'bounding_box': {'height': 32, 'width': 32},
#             'url': 'https://images.genius.com/9ac64405f08557cbf4062b5ca37643e6.1000x1000x1.jpg'},
#            'tiny': {'bounding_box': {'height': 16, 'width': 16},
#             'url': 'https://images.genius.com/9ac64405f08557cbf4062b5ca37643e6.1000x1000x1.jpg'}},
#           'current_user_metadata': {'excluded_permissions': ['follow'],
#            'features': [],
#            'interactions': {'following': False},
#            'permissions': []},
#           'header_image_url': 'https://images.genius.com/49f2b339a8580c0f005a77fffb709a7b.1000x668x1.jpg',
#           'human_readable_role_for_display': 'Staff',
#           'id': 104344,
#           'iq': 1889882,
#           'login': 'streetlights',
#           'name': '\u200bstreetlights',
#           'role_for_display': 'staff',
#           'url': 'https://genius.com/streetlights'}},
#         {'attribution': 0.05172413793103448,
#          'pinned_role': None,
#          'user': {'api_path': '/users/2895026',
#           'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#             'url': 'https://images.rapgenius.com/avatars/medium/cfaeda79c0659c3d39d742b924884454'},
#            'small': {'bounding_box': {'height': 100, 'width': 100},
#             'url': 'https://images.rapgenius.com/avatars/small/cfaeda79c0659c3d39d742b924884454'},
#            'thumb': {'bounding_box': {'height': 32, 'width': 32},
#             'url': 'https://images.rapgenius.com/avatars/thumb/cfaeda79c0659c3d39d742b924884454'},
#            'tiny': {'bounding_box': {'height': 16, 'width': 16},
#             'url': 'https://images.rapgenius.com/avatars/tiny/cfaeda79c0659c3d39d742b924884454'}},
#           'current_user_metadata': {'excluded_permissions': ['follow'],
#            'features': [],
#            'interactions': {'following': False},
#            'permissions': []},
#           'header_image_url': 'https://images.rapgenius.com/avatars/medium/cfaeda79c0659c3d39d742b924884454',
#           'human_readable_role_for_display': None,
#           'id': 2895026,
#           'iq': 139,
#           'login': 'enovid',
#           'name': 'enovid',
#           'role_for_display': None,
#           'url': 'https://genius.com/enovid'}},
#         {'attribution': 0.017241379310344827,
#          'pinned_role': None,
#          'user': {'api_path': '/users/30579',
#           'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#             'url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/1358289005_30579_29756779-300x225.jpg'},
#            'small': {'bounding_box': {'height': 100, 'width': 100},
#             'url': 'https://s3.amazonaws.com/rapgenius/avatars/small/1358289005_30579_29756779-300x225.jpg'},
#            'thumb': {'bounding_box': {'height': 32, 'width': 32},
#             'url': 'https://s3.amazonaws.com/rapgenius/avatars/thumb/1358289005_30579_29756779-300x225.jpg'},
#            'tiny': {'bounding_box': {'height': 16, 'width': 16},
#             'url': 'https://s3.amazonaws.com/rapgenius/avatars/tiny/30579_29756779-300x225.jpg'}},
#           'current_user_metadata': {'excluded_permissions': ['follow'],
#            'features': [],
#            'interactions': {'following': False},
#            'permissions': []},
#           'header_image_url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/1358289005_30579_29756779-300x225.jpg',
#           'human_readable_role_for_display': 'Editor',
#           'id': 30579,
#           'iq': 14031,
#           'login': 'Guv',
#           'name': 'Guv',
#           'role_for_display': 'editor',
#           'url': 'https://genius.com/Guv'}}],
#        'body': {'dom': {'children': [{'children': ['NYC record store Fat Beats relocated in 1996 and celebrated their move by hosting a cypher including the likes of ',
#             {'attributes': {'href': 'https://genius.com/artists/Ill-bill'},
#              'children': ['Ill Bill'],
#              'data': {'api_path': '/artists/1780'},
#              'tag': 'a'},
#             ', ',
#             {'attributes': {'href': 'https://genius.com/artists/Lord-finesse'},
#              'children': ['Lord Finesse'],
#              'data': {'api_path': '/artists/430'},
#              'tag': 'a'},
#             ', ',
#             {'attributes': {'href': 'https://genius.com/artists/Al-tariq'},
#              'children': ["Al' Tariq"],
#              'data': {'api_path': '/artists/3047'},
#              'tag': 'a'},
#             ', ',
#             {'attributes': {'href': 'https://genius.com/artists/Xzibit'},
#              'children': ['Xzibit'],
#              'data': {'api_path': '/artists/291'},
#              'tag': 'a'},
#             ', etc. Out of all of these big names, the 19 year old ',
#             {'attributes': {'href': 'https://genius.com/artists/Kanye-west'},
#              'children': ['Kanye West'],
#              'data': {'api_path': '/artists/72'},
#              'tag': 'a'},
#             ' stood out, debuting this amazing freestyle that would forecast the bright future he would create for himself.'],
#            'tag': 'p'}],
#          'tag': 'root'}},
#        'comment_count': 0,
#        'community': True,
#        'cosigned_by': [],
#        'current_user_metadata': {'excluded_permissions': ['vote',
#          'edit',
#          'cosign',
#          'uncosign',
#          'destroy',
#          'accept',
#          'reject',
#          'see_unreviewed',
#          'clear_votes',
#          'propose_edit_to',
#          'pin_to_profile',
#          'unpin_from_profile',
#          'update_source',
#          'set_brand',
#          'clear_brand',
#          'edit_custom_preview'],
#         'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#         'iq_by_action': {},
#         'permissions': ['create_comment']},
#        'custom_preview': None,
#        'has_voters': True,
#        'id': 3615761,
#        'pinned': False,
#        'rejection_comment': None,
#        'share_url': 'https://genius.com/3615761',
#        'source': None,
#        'state': 'accepted',
#        'url': 'https://genius.com/3615761/Kanye-west-1996-fat-beats-freestyle/1996-fat-beats-freestyle',
#        'verified': False,
#        'verified_by': None,
#        'votes_total': 4}],
#      'annotator_id': 104344,
#      'annotator_login': 'streetlights',
#      'api_path': '/referents/3615761',
#      'classification': 'accepted',
#      'fragment': '1996 Fat Beats Freestyle',
#      'id': 3615761,
#      'is_description': True,
#      'path': '/3615761/Kanye-west-1996-fat-beats-freestyle/1996-fat-beats-freestyle',
#      'range': {'content': '1996 Fat Beats Freestyle'},
#      'song_id': 480181,
#      'url': 'https://genius.com/3615761/Kanye-west-1996-fat-beats-freestyle/1996-fat-beats-freestyle',
#      'verified_annotator_ids': []},
#     'embed_content': "<div id='rg_embed_link_480181' class='rg_embed_link' data-song-id='480181'>Read <a href='https://genius.com/Kanye-west-1996-fat-beats-freestyle-lyrics'>“1996 Fat Beats Freestyle” by Kanye\xa0West</a> on Genius</div> <script crossorigin src='//genius.com/songs/480181/embed.js'></script>",
#     'featured_artists': [],
#     'featured_video': True,
#     'full_title': '1996 Fat Beats Freestyle by\xa0Kanye\xa0West',
#     'header_image_thumbnail_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#     'id': 480181,
# ...
#         'url': 'https://genius.com/Jim-jones-toast-freestyle-runaway-remix-kanye-diss-lyrics'},
#        {'annotation_count': 72,
#         'api_path': '/songs/2402854',
#         'full_title': 'Runaway - Short Film (Part I) by\xa0Screen\xa0Genius (Ft.\xa0Kanye\xa0West)',
#         'header_image_thumbnail_url': 'https://images.rapgenius.com/efc8a3bc53738dfc7cd4f67846e50f71.300x188x1.png',
#         'header_image_url': 'https://images.rapgenius.com/efc8a3bc53738dfc7cd4f67846e50f71.1000x625x1.png',
#         'id': 2402854,
#         'lyrics_owner_id': 1726587,
#         'lyrics_state': 'complete',
#         'path': '/Screen-genius-runaway-short-film-part-i-annotated',
#         'primary_artist': {'api_path': '/artists/185600',
#          'header_image_url': 'https://images.genius.com/a105ca426e365081c955f81b0ba8a89e.283x278x1.png',
#          'id': 185600,
#          'image_url': 'https://images.genius.com/a105ca426e365081c955f81b0ba8a89e.283x278x1.png',
#          'iq': 100,
#          'is_meme_verified': True,
#          'is_verified': True,
#          'name': 'Screen Genius',
#          'url': 'https://genius.com/artists/Screen-genius'},
#         'pyongs_count': 16,
#         'song_art_image_thumbnail_url': 'https://images.rapgenius.com/4885dbe3a69ee780f329a719cf891f91.300x300x1.jpg',
#         'stats': {'hot': False,
#          'pageviews': 10222,
#          'unreviewed_annotations': 0},
#         'title': 'Runaway - Short Film (Part I)',
#         'title_with_featured': 'Runaway - Short Film (Part I) (Ft.\xa0Kanye\xa0West)',
#         'url': 'https://genius.com/Screen-genius-runaway-short-film-part-i-annotated'},
#        {'annotation_count': 1,
#         'api_path': '/songs/3524708',
#         'full_title': "RunAway 18' by\xa0Dot\xa0Cromwell",
#         'header_image_thumbnail_url': 'https://images.genius.com/a4e0627135b48e6428c90eac1207dfba.300x300x1.jpg',
#         'header_image_url': 'https://images.genius.com/a4e0627135b48e6428c90eac1207dfba.800x800x1.jpg',
#         'id': 3524708,
#         'lyrics_owner_id': 54544,
#         'lyrics_state': 'complete',
#         'path': '/Dot-cromwell-runaway-18-lyrics',
#         'primary_artist': {'api_path': '/artists/611031',
#          'header_image_url': 'https://images.genius.com/a1dc3bf797de91fd9a97bd398a30b0e5.1000x667x1.jpg',
#          'id': 611031,
#          'image_url': 'https://images.genius.com/6d58e36087fd715726bf3e541df1ba0d.1000x1000x1.jpg',
#          'iq': 797,
#          'is_meme_verified': False,
#          'is_verified': True,
#          'name': 'Dot Cromwell',
#          'url': 'https://genius.com/artists/Dot-cromwell'},
#         'pyongs_count': None,
#         'song_art_image_thumbnail_url': 'https://images.genius.com/a4e0627135b48e6428c90eac1207dfba.300x300x1.jpg',
#         'stats': {'hot': False, 'unreviewed_annotations': 0},
#         'title': "RunAway 18'",
#         'title_with_featured': "RunAway 18'",
#         'url': 'https://genius.com/Dot-cromwell-runaway-18-lyrics'}],
#       'type': 'sampled_in'},
#      {'songs': [], 'type': 'interpolates'},
#      {'songs': [{'annotation_count': 0,
#         'api_path': '/songs/3287511',
#         'full_title': 'Brand New by\xa0Carti\xa0Bankx',
#         'header_image_thumbnail_url': 'https://images.genius.com/ef08a2fec12117582176dbb6af01f569.300x300x1.jpg',
#         'header_image_url': 'https://images.genius.com/ef08a2fec12117582176dbb6af01f569.499x499x1.jpg',
#         'id': 3287511,
#         'lyrics_owner_id': 5027026,
#         'lyrics_state': 'complete',
#         'path': '/Carti-bankx-brand-new-lyrics',
#         'primary_artist': {'api_path': '/artists/1193283',
#          'header_image_url': 'https://images.genius.com/1a407d0d523028238231b006d254da33.1000x665x1.jpg',
#          'id': 1193283,
#          'image_url': 'https://images.genius.com/b844488bc6a74b30136e444bf2a46d14.718x718x1.jpg',
#          'is_meme_verified': False,
#          'is_verified': False,
#          'name': 'Carti Bankx',
#          'url': 'https://genius.com/artists/Carti-bankx'},
#         'pyongs_count': None,
#         'song_art_image_thumbnail_url': 'https://images.genius.com/ef08a2fec12117582176dbb6af01f569.300x300x1.jpg',
#         'stats': {'hot': False, 'unreviewed_annotations': 0},
#         'title': 'Brand New',
#         'title_with_featured': 'Brand New',
#         'url': 'https://genius.com/Carti-bankx-brand-new-lyrics'}],
#       'type': 'interpolated_by'},
#      {'songs': [], 'type': 'cover_of'},
#      {'songs': [{'annotation_count': 1,
#         'api_path': '/songs/454524',
#         'full_title': 'Runaway by\xa0Silverstein (Ft.\xa0Down\xa0With Webster)',
#         'header_image_thumbnail_url': 'https://images.genius.com/d0d5fc17d4d421287bba7b7b11a3c786.300x300x1.jpg',
#         'header_image_url': 'https://images.genius.com/d0d5fc17d4d421287bba7b7b11a3c786.550x550x1.jpg',
#         'id': 454524,
#         'lyrics_owner_id': 965818,
#         'lyrics_state': 'complete',
#         'path': '/Silverstein-runaway-lyrics',
#         'primary_artist': {'api_path': '/artists/41718',
#          'header_image_url': 'https://images.genius.com/ea2433391141278dbef7ec036ccfd0c9.1000x1000x1.png',
#          'id': 41718,
#          'image_url': 'https://images.genius.com/17d99d47d21c7a42b019ed0e86d3a8c8.960x960x1.jpg',
#          'is_meme_verified': False,
#          'is_verified': False,
#          'name': 'Silverstein',
#          'url': 'https://genius.com/artists/Silverstein'},
#         'pyongs_count': None,
#         'song_art_image_thumbnail_url': 'https://images.genius.com/d0d5fc17d4d421287bba7b7b11a3c786.300x300x1.jpg',
#         'stats': {'hot': False, 'unreviewed_annotations': 0},
#         'title': 'Runaway',
#         'title_with_featured': 'Runaway (Ft.\xa0Down\xa0With Webster)',
#         'url': 'https://genius.com/Silverstein-runaway-lyrics'},
#        {'annotation_count': 1,
#         'api_path': '/songs/3235876',
#         'full_title': 'Runaway by\xa0BiLLLy (Ft.\xa0BETSY)',
#         'header_image_thumbnail_url': 'https://images.genius.com/0effbde278888b39a801b795f820e4f2.300x300x1.jpg',
#         'header_image_url': 'https://images.genius.com/0effbde278888b39a801b795f820e4f2.640x640x1.jpg',
#         'id': 3235876,
#         'lyrics_owner_id': 1821078,
#         'lyrics_state': 'complete',
#         'path': '/Billly-runaway-lyrics',
#         'primary_artist': {'api_path': '/artists/1007634',
#          'header_image_url': 'https://images.genius.com/5b4952b07138f25e94e952e26072dd5e.960x960x1.jpg',
#          'id': 1007634,
#          'image_url': 'https://images.genius.com/5b4952b07138f25e94e952e26072dd5e.960x960x1.jpg',
#          'is_meme_verified': False,
#          'is_verified': False,
#          'name': 'BiLLLy',
#          'url': 'https://genius.com/artists/Billly'},
#         'pyongs_count': None,
#         'song_art_image_thumbnail_url': 'https://images.genius.com/0effbde278888b39a801b795f820e4f2.300x300x1.jpg',
#         'stats': {'hot': False, 'unreviewed_annotations': 0},
#         'title': 'Runaway',
#         'title_with_featured': 'Runaway (Ft.\xa0BETSY)',
#         'url': 'https://genius.com/Billly-runaway-lyrics'}],
#       'type': 'covered_by'},
#      {'songs': [], 'type': 'remix_of'},
#      {'songs': [{'annotation_count': 0,
#         'api_path': '/songs/3508609',
#         'full_title': 'Runaway (HBO® Westworld) by\xa0Ramin\xa0Djawadi',
#         'header_image_thumbnail_url': 'https://images.genius.com/3d236b86677dfa18b0d1fed034a23c1c.300x300x1.jpg',
#         'header_image_url': 'https://images.genius.com/3d236b86677dfa18b0d1fed034a23c1c.939x939x1.jpg',
#         'id': 3508609,
#         'lyrics_owner_id': 104344,
#         'lyrics_state': 'complete',
#         'path': '/Ramin-djawadi-runaway-hbo-westworld-lyrics',
#         'primary_artist': {'api_path': '/artists/52417',
#          'header_image_url': 'https://images.genius.com/26829355465c5c4f45cfcc47e760f115.1000x750x1.jpg',
#          'id': 52417,
#          'image_url': 'https://images.genius.com/0843c9619dd7a7a1457c5c4acbbcfb75.1000x1000x1.png',
#          'is_meme_verified': False,
#          'is_verified': False,
#          'name': 'Ramin Djawadi',
#          'url': 'https://genius.com/artists/Ramin-djawadi'},
#         'pyongs_count': None,
#         'song_art_image_thumbnail_url': 'https://images.genius.com/3d236b86677dfa18b0d1fed034a23c1c.300x300x1.jpg',
#         'stats': {'hot': False, 'unreviewed_annotations': 0},
#         'title': 'Runaway (HBO® Westworld)',
#         'title_with_featured': 'Runaway (HBO® Westworld)',
#         'url': 'https://genius.com/Ramin-djawadi-runaway-hbo-westworld-lyrics'},
#        {'annotation_count': 0,
#         'api_path': '/songs/3603753',
#         'full_title': 'RUNNAWAY FREESTYLE by\xa0Juice\xa0WRLD',
#         'header_image_thumbnail_url': 'https://images.genius.com/eaff0313fe57c1e3e14b32bf76ea5bff.300x300x1.png',
#         'header_image_url': 'https://images.genius.com/eaff0313fe57c1e3e14b32bf76ea5bff.501x501x1.png',
#         'id': 3603753,
#         'lyrics_owner_id': 792338,
#         'lyrics_state': 'complete',
#         'path': '/Juice-wrld-runnaway-freestyle-lyrics',
#         'primary_artist': {'api_path': '/artists/1237094',
#          'header_image_url': 'https://images.genius.com/2e13d5844ff75c9ef8be598a6c661836.430x430x1.jpg',
#          'id': 1237094,
#          'image_url': 'https://images.genius.com/2e13d5844ff75c9ef8be598a6c661836.430x430x1.jpg',
#          'is_meme_verified': False,
#          'is_verified': False,
#          'name': 'Juice WRLD',
#          'url': 'https://genius.com/artists/Juice-wrld'},
#         'pyongs_count': None,
#         'song_art_image_thumbnail_url': 'https://images.genius.com/eaff0313fe57c1e3e14b32bf76ea5bff.300x300x1.png',
#         'stats': {'hot': False, 'unreviewed_annotations': 0},
#         'title': 'RUNNAWAY FREESTYLE',
#         'title_with_featured': 'RUNNAWAY FREESTYLE',
#         'url': 'https://genius.com/Juice-wrld-runnaway-freestyle-lyrics'}],
#       'type': 'remixed_by'},
#      {'songs': [], 'type': 'live_version_of'},
#      {'songs': [], 'type': 'performed_live_as'}],
#     'stats': {'accepted_annotations': 22,
#      'concurrents': 7,
#      'contributors': 258,
#      'hot': False,
#      'iq_earners': 258,
#      'pageviews': 1394479,
#      'transcribers': 0,
#      'unreviewed_annotations': 0,
#      'verified_annotations': 2},
#     'title': 'Runaway',
#     'title_with_featured': 'Runaway (Ft.\xa0Pusha\xa0T)',
#     'url': 'https://genius.com/Kanye-west-runaway-lyrics',
#     'verified_annotations_by': [{'api_path': '/users/106965',
#       'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#         'url': 'https://images.genius.com/avatars/medium/b4cf929b98700ecf9e9ca438766fa1fe'},
#        'small': {'bounding_box': {'height': 100, 'width': 100},
#         'url': 'https://images.genius.com/avatars/small/b4cf929b98700ecf9e9ca438766fa1fe'},
#        'thumb': {'bounding_box': {'height': 32, 'width': 32},
#         'url': 'https://images.genius.com/avatars/thumb/b4cf929b98700ecf9e9ca438766fa1fe'},
#        'tiny': {'bounding_box': {'height': 16, 'width': 16},
#         'url': 'https://images.genius.com/avatars/tiny/b4cf929b98700ecf9e9ca438766fa1fe'}},
#       'current_user_metadata': {'excluded_permissions': ['follow'],
#        'features': [],
#        'interactions': {'following': False},
#        'permissions': []},
#       'header_image_url': 'https://images.genius.com/1bc34e5deca22b440c5d186ef06720f2.1000x668x1.jpg',
#       'human_readable_role_for_display': 'Verified Artist',
#       'id': 106965,
#       'iq': 41845,
#       'login': 'PushaT',
#       'name': 'Pusha T',
#       'role_for_display': 'verified_artist',
#       'url': 'https://genius.com/PushaT'}],
#     'verified_contributors': [{'artist': {'api_path': '/artists/643',
#        'header_image_url': 'https://images.genius.com/1bc34e5deca22b440c5d186ef06720f2.1000x668x1.jpg',
#        'id': 643,
#        'image_url': 'https://images.genius.com/841bd78ee6df05aba464d4c63d5d5e97.658x329x1.jpg',
#        'iq': 41845,
#        'is_meme_verified': True,
#        'is_verified': True,
#        'name': 'Pusha T',
#        'url': 'https://genius.com/artists/Pusha-t'},
#       'contributions': ['annotations'],
#       'user': {'api_path': '/users/106965',
#        'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#          'url': 'https://images.genius.com/avatars/medium/b4cf929b98700ecf9e9ca438766fa1fe'},
#         'small': {'bounding_box': {'height': 100, 'width': 100},
#          'url': 'https://images.genius.com/avatars/small/b4cf929b98700ecf9e9ca438766fa1fe'},
#         'thumb': {'bounding_box': {'height': 32, 'width': 32},
#          'url': 'https://images.genius.com/avatars/thumb/b4cf929b98700ecf9e9ca438766fa1fe'},
#         'tiny': {'bounding_box': {'height': 16, 'width': 16},
#          'url': 'https://images.genius.com/avatars/tiny/b4cf929b98700ecf9e9ca438766fa1fe'}},
#        'current_user_metadata': {'excluded_permissions': ['follow'],
#         'features': [],
#         'interactions': {'following': False},
#         'permissions': []},
#        'header_image_url': 'https://images.genius.com/1bc34e5deca22b440c5d186ef06720f2.1000x668x1.jpg',
#        'human_readable_role_for_display': 'Verified Artist',
#        'id': 106965,
#        'iq': 41845,
#        'login': 'PushaT',
#        'name': 'Pusha T',
#        'role_for_display': 'verified_artist',
#        'url': 'https://genius.com/PushaT'}}],
#     'verified_lyrics_by': [],
#     'writer_artists': [{'api_path': '/artists/27434',
#       'header_image_url': 'https://images.genius.com/c8a8394c36c41ac9fe3e7edb431eef96.553x369x1.jpg',
#       'id': 27434,
#       'image_url': 'https://images.genius.com/1c5df467876ffc603f67612eec12a31c.358x358x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Jeff Bhasker',
#       'url': 'https://genius.com/artists/Jeff-bhasker'},
#      {'api_path': '/artists/643',
#       'header_image_url': 'https://images.genius.com/1bc34e5deca22b440c5d186ef06720f2.1000x668x1.jpg',
#       'id': 643,
#       'image_url': 'https://images.genius.com/841bd78ee6df05aba464d4c63d5d5e97.658x329x1.jpg',
#       'iq': 41845,
#       'is_meme_verified': True,
#       'is_verified': True,
#       'name': 'Pusha T',
#       'url': 'https://genius.com/artists/Pusha-t'},
#      {'api_path': '/artists/645343',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1523560690',
#       'id': 645343,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1523560690',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'John Branch',
#       'url': 'https://genius.com/artists/John-branch'},
#      {'api_path': '/artists/5454',
#       'header_image_url': 'https://images.genius.com/7635c23b7b8f64cf5817536b85b47ce7.330x330x1.jpg',
#       'id': 5454,
#       'image_url': 'https://images.genius.com/7635c23b7b8f64cf5817536b85b47ce7.330x330x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Malik Yusef',
#       'url': 'https://genius.com/artists/Malik-yusef'},
#      {'api_path': '/artists/7161',
#       'header_image_url': 'https://images.genius.com/687c19cf89ca24354a5c2da7721508a9.1000x561x1.jpg',
#       'id': 7161,
#       'image_url': 'https://images.genius.com/886dffb3248cadf5e151f3e92dcca1eb.785x785x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Mike Dean',
#       'url': 'https://genius.com/artists/Mike-dean'},
#      {'api_path': '/artists/27453',
#       'header_image_url': 'https://images.genius.com/5bbf61d5c1190802e70b8bd9aabde87b.400x400x1.jpg',
#       'id': 27453,
#       'image_url': 'https://images.genius.com/5bbf61d5c1190802e70b8bd9aabde87b.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Emile Haynie',
#       'url': 'https://genius.com/artists/Emile-haynie'},
#      {'api_path': '/artists/72',
#       'header_image_url': 'https://images.genius.com/93a98116162c07aa60e8a15fe7fb6977.800x480x1.jpg',
#       'id': 72,
#       'image_url': 'https://images.genius.com/2182acf08ba673008132b0278baff86a.803x803x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Kanye West',
#       'url': 'https://genius.com/artists/Kanye-west'}]},
#    'title': 'Runaway',
#    'year': '2010-10-10'}]}
